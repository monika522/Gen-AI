# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# ...

# %%
import os
# Replace with your Hugging Face API token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "your_huggingface_api_token_here"

# %%
from langchain.llms import HuggingFaceHub

# Replace with your Hugging Face API token
llm = HuggingFaceHub(repo_id="google/flan-t5-small", huggingfacehub_api_token="your_huggingface_api_token_here")
# Out:
# <ipython-input-3-7fbceb8ec0f7>:4: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(repo_id="google/flan-t5-small", huggingfacehub_api_token="your_huggingface_api_token_here")

# %%
# Install necessary libraries
# !pip install -U langchain faiss-cpu transformers

# Import required modules
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceHub
from langchain.schema import Document

# Step 1: Set Hugging Face API Token
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "Your token"  # Replace with your token

# Example text data
text = """
LangChain is a framework for developing applications powered by LLMs (Large Language Models).
It simplifies the process of integrating language models with external data sources, like databases or documents, and enables more advanced features like memory and document retrieval.
"""
documents = [Document(page_content=text)]  # Wrap text in a Document

# Step 2: Split the documents into chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(documents)

# Step 3: Create embeddings for the document chunks using HuggingFace embeddings
embeddings = HuggingFaceEmbeddings()

# Step 4: Create a FAISS vector store
vector_store = FAISS.from_documents(chunks, embeddings)

# Step 5: Set up the retriever (for document retrieval during querying)
retriever = vector_store.as_retriever()

# Step 6: Set up the LLM for generation using HuggingFaceHub
llm = HuggingFaceHub(repo_id="google/flan-t5-small")  # Hugging Face model, publicly available

# Step 7: Set up the RetrievalQA chain (this links retrieval and generation)
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",  # "stuff" combines the documents for retrieval into a single prompt
    retriever=retriever
)

# Step 8: Ask a question based on the loaded document
query = "What is LangChain?"
response = qa_chain.run(query)

# Step 9: Display the result
print("Answer:", response)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 85.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.2
#     Uninstalling transformers-4.46.2:
#       Successfully uninstalled transformers-4.46.2
# ...
# <ipython-input-4-0c382e374f81>:29: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings()
# ...
